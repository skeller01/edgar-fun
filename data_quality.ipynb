# %%
#############################################################
#  CELL 1: Markdown
#############################################################

# Example text for a Markdown cell:
"""
# Data Quality Report for N-PX CSV Outputs

This notebook performs basic data quality checks on the CSV files generated
by the N-PX parsing workflow. We’ll look for:

1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).
2. **Column-level stats**: For each column, how many nulls or missing values?
3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?
4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.

Feel free to add more custom checks, such as:
- Checking valid ranges for numeric columns.
- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).
- Checking that enumerated columns contain only valid values.

Let's begin!
"""
# Out:
# "\n# Data Quality Report for N-PX CSV Outputs\n\nThis notebook performs basic data quality checks on the CSV files generated\nby the N-PX parsing workflow. We’ll look for:\n\n1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).\n2. **Column-level stats**: For each column, how many nulls or missing values?\n3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?\n4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.\n\nFeel free to add more custom checks, such as:\n- Checking valid ranges for numeric columns.\n- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).\n- Checking that enumerated columns contain only valid values.\n\nLet's begin!\n"

# %%
#############################################################
#  CELL 2: Imports & Setup
#############################################################

import os
import pandas as pd

# Point this to the folder where your CSVs are stored
CSV_FOLDER = "output"

# List your tables and corresponding file names
CSV_FILES = {
    "form_npx": "form_npx.csv",
    "institutional_manager": "institutional_manager.csv",
    "series": "series.csv",
    "proxy_voting_record": "proxy_voting_record.csv",
    "matter_category": "matter_category.csv",
    "proxy_voting_record_category": "proxy_voting_record_category.csv",
    "voting_record_manager": "voting_record_manager.csv",
    "voting_record_series": "voting_record_series.csv"
}

# We'll load all of them into a dict of DataFrames.
dfs = {}
for table_name, file_name in CSV_FILES.items():
    path = os.path.join(CSV_FOLDER, file_name)
    if os.path.exists(path):
        df = pd.read_csv(path)
        dfs[table_name] = df
    else:
        print(f"[Warning] {file_name} not found in {CSV_FOLDER}!")
        dfs[table_name] = None

print("DataFrames loaded:")
for k,v in dfs.items():
    if v is not None:
        print(f" - {k}: {len(v)} rows")
    else:
        print(f" - {k}: No data (file missing).")
# Out:
# C:\Users\skell\AppData\Local\Temp\ipykernel_3908\2531012235.py:28: DtypeWarning: Columns (5,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# DataFrames loaded:
#  - form_npx: 300 rows
#  - institutional_manager: 78 rows
#  - series: 346 rows
#  - proxy_voting_record: 539898 rows
#  - matter_category: 16 rows
#  - proxy_voting_record_category: 555658 rows
#  - voting_record_manager: 63729 rows
#  - voting_record_series: 444958 rows

# %%
#############################################################
#  CELL 3: Basic Data Quality Checks
#############################################################

# We’ll create a function to do quick checks on a given DataFrame.
def data_quality_report(df, df_name):
    """
    Print a small summary of data quality for a given DataFrame:
    1. Number of rows & columns
    2. Column data types & non-null counts
    3. Percent missing per column
    4. Sample records (head)
    """
    print(f"\n=== Data Quality Report: {df_name} ===")

    if df is None or df.empty:
        print("No data or empty DataFrame!")
        return

    # 1) Shape
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")

    # 2) Info
    print("\n--- Info ---")
    print(df.info())

    # 3) Missing values
    print("\n--- Missing Values (absolute / percent) ---")
    missing_count = df.isna().sum()
    missing_percent = (df.isna().mean() * 100).round(2)
    for col in df.columns:
        print(f"   {col}: {missing_count[col]} / {missing_percent[col]}%")

    # 4) Quick sample
    print("\n--- Sample Rows ---")
    print(df.head(3))

    # 5) (Optional) Check for duplicates. For small tables, a naive approach:
    #    We won't fix them here, just report.
    dup_count = df.duplicated().sum()
    if dup_count > 0:
        print(f"\n[Warning] {dup_count} duplicate row(s) found in {df_name}.")
    else:
        print("\nNo duplicate rows found.")

    # 6) (Optional) If you have a PK column, check duplicates in that PK:
    # if "form_id" in df.columns:
    #    pk_dup_count = df.duplicated(subset=["form_id"]).sum()
    #    if pk_dup_count > 0:
    #        print(f"[Warning] form_id has {pk_dup_count} duplicates!")
    #    else:
    #        print("form_id column is unique.")


# Now run the data_quality_report for each table
for table_name, df in dfs.items():
    data_quality_report(df, table_name)
# Out:
# === Data Quality Report: form_npx ===
# Shape: 300 rows x 38 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   form_id                         300 non-null    int64
#  1   form_type                       300 non-null    object
#  2   registrant_type                 300 non-null    object
#  3   live_test_flag                  300 non-null    object
#  4   cik                             300 non-null    int64
#  5   phone_number                    300 non-null    object
#  6   investment_company_type         86 non-null     object
#  7   conformed_period                300 non-null    object
#  8   year_or_quarter                 300 non-null    object
#  9   report_calendar_year            297 non-null    float64
#  10  report_quarter_year             3 non-null      float64
#  11  report_type                     300 non-null    object
#  12  confidential_treatment          300 non-null    object
#  13  is_notice_report                300 non-null    bool
#  14  is_amendment                    300 non-null    bool
#  15  amendment_no                    0 non-null      float64
#  16  amendment_type                  0 non-null      float64
#  17  reason_for_non_confidentiality  0 non-null      float64
#  18  crd_number                      113 non-null    float64
#  19  sec_file_number_other           92 non-null     object
#  20  lei_number                      77 non-null     object
#  21  sec_file_number                 300 non-null    object
#  22  explanatory_choice              300 non-null    object
#  23  explanatory_notes               28 non-null     object
#  24  other_included_managers_count   300 non-null    int64
#  25  reporting_person_name           300 non-null    object
#  26  address_street1                 300 non-null    object
#  27  address_street2                 138 non-null    object
#  28  address_city                    300 non-null    object
#  29  address_state                   300 non-null    object
#  30  address_country                 300 non-null    object
#  31  address_zip                     300 non-null    object
#  32  signatory_name                  300 non-null    object
#  33  signatory_name_printed          300 non-null    object
#  34  signatory_title                 300 non-null    object
#  35  signatory_date                  300 non-null    object
#  36  accession_number                300 non-null    object
#  37  date_filed                      300 non-null    object
# dtypes: bool(2), float64(6), int64(3), object(27)
# memory usage: 85.1+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_id: 0 / 0.0%
#    form_type: 0 / 0.0%
#    registrant_type: 0 / 0.0%
#    live_test_flag: 0 / 0.0%
#    cik: 0 / 0.0%
#    phone_number: 0 / 0.0%
#    investment_company_type: 214 / 71.33%
#    conformed_period: 0 / 0.0%
#    year_or_quarter: 0 / 0.0%
#    report_calendar_year: 3 / 1.0%
#    report_quarter_year: 297 / 99.0%
#    report_type: 0 / 0.0%
#    confidential_treatment: 0 / 0.0%
#    is_notice_report: 0 / 0.0%
#    is_amendment: 0 / 0.0%
#    amendment_no: 300 / 100.0%
#    amendment_type: 300 / 100.0%
#    reason_for_non_confidentiality: 300 / 100.0%
#    crd_number: 187 / 62.33%
#    sec_file_number_other: 208 / 69.33%
#    lei_number: 223 / 74.33%
#    sec_file_number: 0 / 0.0%
#    explanatory_choice: 0 / 0.0%
#    explanatory_notes: 272 / 90.67%
#    other_included_managers_count: 0 / 0.0%
#    reporting_person_name: 0 / 0.0%
#    address_street1: 0 / 0.0%
#    address_street2: 162 / 54.0%
#    address_city: 0 / 0.0%
#    address_state: 0 / 0.0%
#    address_country: 0 / 0.0%
#    address_zip: 0 / 0.0%
#    signatory_name: 0 / 0.0%
#    signatory_name_printed: 0 / 0.0%
#    signatory_title: 0 / 0.0%
#    signatory_date: 0 / 0.0%
#    accession_number: 0 / 0.0%
#    date_filed: 0 / 0.0%
#
# --- Sample Rows ---
#    form_id form_type registrant_type live_test_flag      cik  phone_number  \
# 0        1      N-PX              IM           LIVE  1536924    6157623163
# 1        2      N-PX              IM           LIVE  1896711    8476561111
# 2        3      N-PX              IM           LIVE  1009198  417-777-7677
#
#   investment_company_type conformed_period year_or_quarter  \
# 0                     NaN       2024-06-30            YEAR
# 1                     NaN       2024-06-30            YEAR
# 2                     NaN       2024-06-30            YEAR
#
#    report_calendar_year  ...  address_city address_state address_country  \
# 0                2024.0  ...     BRENTWOOD            TN              US
# 1                2024.0  ...    NORTHBROOK            IL              US
# 2                2024.0  ...       BOLIVAR            MO              US
#
#    address_zip   signatory_name  signatory_name_printed  \
# 0        37027      Tracey Hill             Tracey Hill
# 1        60062  Walter M. Kelly         Walter M. Kelly
# 2        65613      James Jones             James Jones
#
#             signatory_title  signatory_date      accession_number  date_filed
# 0  Chief Compliance Officer      2024-07-01  0001536924-24-000004  2024-07-01
# 1  Chief Compliance Officer      2024-07-02  0001896711-24-000005  2024-07-03
# 2           Managing Member      2024-07-08  0001085146-24-002795  2024-07-09
#
# [3 rows x 38 columns]
#
# No duplicate rows found.
#
# === Data Quality Report: institutional_manager ===
# Shape: 78 rows x 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manager_id       78 non-null     int64
#  1   form_id          78 non-null     int64
#  2   serial_no        64 non-null     float64
#  3   name             64 non-null     object
#  4   form13f_number   64 non-null     object
#  5   crd_number       32 non-null     float64
#  6   sec_file_number  30 non-null     object
#  7   lei_number       24 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.0+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    manager_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    serial_no: 14 / 17.95%
#    name: 14 / 17.95%
#    form13f_number: 14 / 17.95%
#    crd_number: 46 / 58.97%
#    sec_file_number: 48 / 61.54%
#    lei_number: 54 / 69.23%
#
# --- Sample Rows ---
#    manager_id  form_id  serial_no               name form13f_number  \
# 0           1       53      801.0  William Oldfather      028-19711
# 1           2       58        NaN                NaN            NaN
# 2           3       86        NaN                NaN            NaN
#
#    crd_number sec_file_number lei_number
# 0    112505.0             NaN        NaN
# 1         NaN             NaN        NaN
# 2         NaN             NaN        NaN
#
# No duplicate rows found.
#
# === Data Quality Report: series ===
# Shape: 346 rows x 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   series_id    346 non-null    int64
#  1   form_id      346 non-null    int64
#  2   series_code  346 non-null    object
#  3   series_name  346 non-null    object
#  4   series_lei   346 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 13.6+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    series_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    series_code: 0 / 0.0%
#    series_name: 0 / 0.0%
#    series_lei: 0 / 0.0%
#
# --- Sample Rows ---
#    series_id  form_id series_code  \
# 0          1       14  S000012149
# 1          2       14  S000012150
# 2          3       16  S000059809
#
#                                          series_name            series_lei
# 0                                         Manor Fund  5493002T1EXM7FL8WW21
# 1                                        Growth Fund  549300VOR8OSZEDINY65
# 2  Dreyfus Treasury and Agency Liquidity Money Ma...  549300PYJOW0O9S0U493
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record ===
# Shape: 539898 rows x 15 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539898 entries, 0 to 539897
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   vote_id           539898 non-null  int64
#  1   form_id           539898 non-null  int64
#  2   issuer_name       539898 non-null  object
#  3   cusip             493085 non-null  object
#  4   isin              469759 non-null  object
#  5   figi              1102 non-null    object
#  6   meeting_date      539752 non-null  object
#  7   vote_description  539898 non-null  object
#  8   proposed_by       496429 non-null  object
#  9   shares_voted      539895 non-null  float64
#  10  shares_on_loan    539897 non-null  float64
#  11  vote_cast         503908 non-null  object
#  12  vote_cast_shares  504545 non-null  float64
#  13  management_rec    504554 non-null  object
#  14  other_notes       1037 non-null    object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 61.8+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    issuer_name: 0 / 0.0%
#    cusip: 46813 / 8.67%
#    isin: 70139 / 12.99%
#    figi: 538796 / 99.8%
#    meeting_date: 146 / 0.03%
#    vote_description: 0 / 0.0%
#    proposed_by: 43469 / 8.05%
#    shares_voted: 3 / 0.0%
#    shares_on_loan: 1 / 0.0%
#    vote_cast: 35990 / 6.67%
#    vote_cast_shares: 35353 / 6.55%
#    management_rec: 35344 / 6.55%
#    other_notes: 538861 / 99.81%
#
# --- Sample Rows ---
#    vote_id  form_id              issuer_name      cusip          isin figi  \
# 0        1        4  CRA International, Inc.  12618T105  US12618T1051  NaN
# 1        2        4  CRA International, Inc.  12618T105  US12618T1051  NaN
# 2        3        4         PowerFleet, Inc.  73931J109  US73931J1097  NaN
#
#   meeting_date                                   vote_description proposed_by  \
# 0   2023-07-13  To approve, on an advisory basis, the compensa...         NaN
# 1   2023-07-13  To approve, on an advisory basis, the preferre...         NaN
# 2   2023-07-20  Advisory approval of the Company's executive c...         NaN
#
#    shares_voted  shares_on_loan vote_cast  vote_cast_shares management_rec  \
# 0       68507.0             0.0       FOR           68507.0            FOR
# 1       68507.0             0.0    1 YEAR           68507.0            FOR
# 2     4255350.0             0.0       FOR         4255350.0            FOR
#
#   other_notes
# 0         NaN
# 1         NaN
# 2         NaN
#
# No duplicate rows found.
#
# === Data Quality Report: matter_category ===
# Shape: 16 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    16 non-null     int64
#  1   category_type  16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    category_id: 0 / 0.0%
#    category_type: 0 / 0.0%
#
# --- Sample Rows ---
#    category_id                 category_type
# 0            1  SECTION 14A SAY-ON-PAY VOTES
# 1            2            DIRECTOR ELECTIONS
# 2            3                         OTHER
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record_category ===
# Shape: 555658 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555658 entries, 0 to 555657
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   vote_id      555658 non-null  int64
#  1   category_id  555658 non-null  int64
# dtypes: int64(2)
# memory usage: 8.5 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    category_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  category_id
# 0        1            1
# 1        2            1
# 2        3            1
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_manager ===
# Shape: 63729 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63729 entries, 0 to 63728
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vote_id     63729 non-null  int64
#  1   manager_id  63729 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 995.9+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    manager_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id manager_id
# 0     4339        801
# 1     4340        801
# 2     4341        801
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_series ===
# Shape: 444958 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444958 entries, 0 to 444957
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   vote_id    444958 non-null  int64
#  1   series_id  444958 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.8+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    series_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id   series_id
# 0      316  S000012149
# 1      317  S000012149
# 2      318  S000012149
#
# No duplicate rows found.

# %%
#############################################################
#  CELL 4: Additional Cross-Checks (Optional)
#############################################################

# Example cross-check: Ensure that proxy_voting_record_category.vote_id 
# actually exists in proxy_voting_record.vote_id
if dfs["proxy_voting_record"] is not None and not dfs["proxy_voting_record"].empty:
    if dfs["proxy_voting_record_category"] is not None and not dfs["proxy_voting_record_category"].empty:
        # Put them in sets for quick membership test
        valid_vote_ids = set(dfs["proxy_voting_record"]["vote_id"].dropna().unique())
        cat_vote_ids = set(dfs["proxy_voting_record_category"]["vote_id"].dropna().unique())
        
        missing_vote_ids = cat_vote_ids - valid_vote_ids
        if missing_vote_ids:
            print(f"\n[Cross-check] Found {len(missing_vote_ids)} vote_id(s) in proxy_voting_record_category not in proxy_voting_record.")
            print("Missing IDs:", missing_vote_ids)
        else:
            print("\n[Cross-check] All category vote_ids exist in proxy_voting_record!")

# You can similarly check that 'form_id' in institutional_manager, series, etc. 
# actually appears in form_npx.
# Out:
# [Cross-check] All category vote_ids exist in proxy_voting_record!
