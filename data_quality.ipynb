# %%
#############################################################
#  CELL 1: Markdown
#############################################################

# Example text for a Markdown cell:
"""
# Data Quality Report for N-PX CSV Outputs

This notebook performs basic data quality checks on the CSV files generated
by the N-PX parsing workflow. We’ll look for:

1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).
2. **Column-level stats**: For each column, how many nulls or missing values?
3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?
4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.

Feel free to add more custom checks, such as:
- Checking valid ranges for numeric columns.
- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).
- Checking that enumerated columns contain only valid values.

Let's begin!
"""
# Out:
# "\n# Data Quality Report for N-PX CSV Outputs\n\nThis notebook performs basic data quality checks on the CSV files generated\nby the N-PX parsing workflow. We’ll look for:\n\n1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).\n2. **Column-level stats**: For each column, how many nulls or missing values?\n3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?\n4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.\n\nFeel free to add more custom checks, such as:\n- Checking valid ranges for numeric columns.\n- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).\n- Checking that enumerated columns contain only valid values.\n\nLet's begin!\n"

# %%
#############################################################
#  CELL 2: Imports & Setup
#############################################################

import os
import pandas as pd

# Point this to the folder where your CSVs are stored
CSV_FOLDER = "output"

# List your tables and corresponding file names
CSV_FILES = {
    "form_npx": "form_npx.csv",
    "institutional_manager": "institutional_manager.csv",
    "series": "series.csv",
    "proxy_voting_record": "proxy_voting_record.csv",
    "matter_category": "matter_category.csv",
    "proxy_voting_record_category": "proxy_voting_record_category.csv",
    "voting_record_manager": "voting_record_manager.csv",
    "voting_record_series": "voting_record_series.csv"
}

# We'll load all of them into a dict of DataFrames.
dfs = {}
for table_name, file_name in CSV_FILES.items():
    path = os.path.join(CSV_FOLDER, file_name)
    if os.path.exists(path):
        df = pd.read_csv(path)
        dfs[table_name] = df
    else:
        print(f"[Warning] {file_name} not found in {CSV_FOLDER}!")
        dfs[table_name] = None

print("DataFrames loaded:")
for k,v in dfs.items():
    if v is not None:
        print(f" - {k}: {len(v)} rows")
    else:
        print(f" - {k}: No data (file missing).")
# Out:
# C:\Users\skell\AppData\Local\Temp\ipykernel_22964\2531012235.py:28: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# DataFrames loaded:
#  - form_npx: 82 rows
#  - institutional_manager: 38 rows
#  - series: 84 rows
#  - proxy_voting_record: 184253 rows
#  - matter_category: 14 rows
#  - proxy_voting_record_category: 186694 rows
#  - voting_record_manager: 25231 rows
#  - voting_record_series: 77424 rows

# %%
#############################################################
#  CELL 3: Basic Data Quality Checks
#############################################################

# We’ll create a function to do quick checks on a given DataFrame.
def data_quality_report(df, df_name):
    """
    Print a small summary of data quality for a given DataFrame:
    1. Number of rows & columns
    2. Column data types & non-null counts
    3. Percent missing per column
    4. Sample records (head)
    """
    print(f"\n=== Data Quality Report: {df_name} ===")

    if df is None or df.empty:
        print("No data or empty DataFrame!")
        return

    # 1) Shape
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")

    # 2) Info
    print("\n--- Info ---")
    print(df.info())

    # 3) Missing values
    print("\n--- Missing Values (absolute / percent) ---")
    missing_count = df.isna().sum()
    missing_percent = (df.isna().mean() * 100).round(2)
    for col in df.columns:
        print(f"   {col}: {missing_count[col]} / {missing_percent[col]}%")

    # 4) Quick sample
    print("\n--- Sample Rows ---")
    print(df.head(3))

    # 5) (Optional) Check for duplicates. For small tables, a naive approach:
    #    We won't fix them here, just report.
    dup_count = df.duplicated().sum()
    if dup_count > 0:
        print(f"\n[Warning] {dup_count} duplicate row(s) found in {df_name}.")
    else:
        print("\nNo duplicate rows found.")

    # 6) (Optional) If you have a PK column, check duplicates in that PK:
    # if "form_id" in df.columns:
    #    pk_dup_count = df.duplicated(subset=["form_id"]).sum()
    #    if pk_dup_count > 0:
    #        print(f"[Warning] form_id has {pk_dup_count} duplicates!")
    #    else:
    #        print("form_id column is unique.")


# Now run the data_quality_report for each table
for table_name, df in dfs.items():
    data_quality_report(df, table_name)
# Out:
# === Data Quality Report: form_npx ===
# Shape: 82 rows x 32 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   form_id                        82 non-null     int64
#  1   reporting_person_name          82 non-null     object
#  2   phone_number                   82 non-null     object
#  3   address_street1                82 non-null     object
#  4   address_street2                32 non-null     object
#  5   address_city                   82 non-null     object
#  6   address_state                  82 non-null     object
#  7   address_zip                    82 non-null     object
#  8   accession_number               82 non-null     object
#  9   cik                            82 non-null     int64
#  10  conformed_period               82 non-null     object
#  11  date_filed                     82 non-null     object
#  12  report_type                    82 non-null     object
#  13  form_type                      82 non-null     object
#  14  sec_file_number                82 non-null     object
#  15  crd_number                     26 non-null     float64
#  16  sec_file_number_other          29 non-null     object
#  17  lei_number                     28 non-null     object
#  18  investment_company_type        29 non-null     object
#  19  confidential_treatment         82 non-null     object
#  20  is_notice_report               82 non-null     bool
#  21  explanatory_choice             82 non-null     object
#  22  other_included_managers_count  82 non-null     int64
#  23  series_count                   82 non-null     int64
#  24  is_amendment                   82 non-null     bool
#  25  amendment_no                   82 non-null     int64
#  26  amendment_type                 82 non-null     object
#  27  notice_explanation             19 non-null     object
#  28  signatory_name                 82 non-null     object
#  29  signatory_name_printed         82 non-null     object
#  30  signatory_title                82 non-null     object
#  31  signatory_date                 82 non-null     object
# dtypes: bool(2), float64(1), int64(5), object(24)
# memory usage: 19.5+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_id: 0 / 0.0%
#    reporting_person_name: 0 / 0.0%
#    phone_number: 0 / 0.0%
#    address_street1: 0 / 0.0%
#    address_street2: 50 / 60.98%
#    address_city: 0 / 0.0%
#    address_state: 0 / 0.0%
#    address_zip: 0 / 0.0%
#    accession_number: 0 / 0.0%
#    cik: 0 / 0.0%
#    conformed_period: 0 / 0.0%
#    date_filed: 0 / 0.0%
#    report_type: 0 / 0.0%
#    form_type: 0 / 0.0%
#    sec_file_number: 0 / 0.0%
#    crd_number: 56 / 68.29%
#    sec_file_number_other: 53 / 64.63%
#    lei_number: 54 / 65.85%
#    investment_company_type: 53 / 64.63%
#    confidential_treatment: 0 / 0.0%
#    is_notice_report: 0 / 0.0%
#    explanatory_choice: 0 / 0.0%
#    other_included_managers_count: 0 / 0.0%
#    series_count: 0 / 0.0%
#    is_amendment: 0 / 0.0%
#    amendment_no: 0 / 0.0%
#    amendment_type: 0 / 0.0%
#    notice_explanation: 63 / 76.83%
#    signatory_name: 0 / 0.0%
#    signatory_name_printed: 0 / 0.0%
#    signatory_title: 0 / 0.0%
#    signatory_date: 0 / 0.0%
#
# --- Sample Rows ---
#    form_id          reporting_person_name    phone_number  \
# 0        1              MVM Partners, LLC    617-383-2106
# 1        2  Erickson Financial Group, LLC  (484) 209-5270
# 2        3     Private Advisory Group LLC    425 498-2320
#
#         address_street1   address_street2 address_city address_state  \
# 0         OLD CITY HALL  45 SCHOOL STREET       BOSTON            MA
# 1   33 SOUTH 7TH STREET         SUITE 300    ALLENTOWN            PA
# 2  16880 NE 79TH STREET               NaN      REDMOND            WA
#
#   address_zip      accession_number      cik  ...  \
# 0       02108  0000950159-24-000231  1947083  ...
# 1       18101  0001951757-24-000658  1797734  ...
# 2       98052  0001632965-24-000010  1632965  ...
#
#   other_included_managers_count series_count is_amendment amendment_no  \
# 0                             0            0         True            1
# 1                             0            0         True            1
# 2                             0            0         True            1
#
#   amendment_type  notice_explanation      signatory_name  \
# 0    RESTATEMENT                 NaN  /s/ Eric Bednarski
# 1    RESTATEMENT                 NaN    Timothy Erickson
# 2    RESTATEMENT                 NaN         Jon Bishopp
#
#   signatory_name_printed           signatory_title signatory_date
# 0     /s/ Eric Bednarski            Vice President     2024-07-26
# 1       Timothy Erickson  Chief Compliance Officer     2024-08-05
# 2            Jon Bishopp  Chief Compliance Officer     2024-08-08
#
# [3 rows x 32 columns]
#
# No duplicate rows found.
#
# === Data Quality Report: institutional_manager ===
# Shape: 38 rows x 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manager_id       38 non-null     int64
#  1   form_id          38 non-null     int64
#  2   serial_no        30 non-null     float64
#  3   name             38 non-null     object
#  4   form13f_number   27 non-null     object
#  5   crd_number       7 non-null      float64
#  6   sec_file_number  13 non-null     object
#  7   lei_number       16 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.5+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    manager_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    serial_no: 8 / 21.05%
#    name: 0 / 0.0%
#    form13f_number: 11 / 28.95%
#    crd_number: 31 / 81.58%
#    sec_file_number: 25 / 65.79%
#    lei_number: 22 / 57.89%
#
# --- Sample Rows ---
#    manager_id  form_id  serial_no                            name  \
# 0           1       10        NaN                The Cutler Trust
# 1           2       19        NaN  NOMURA ASSET MANAGEMENT CO LTD
# 2           3       24        NaN                 The Merger Fund
#
#   form13f_number  crd_number sec_file_number            lei_number
# 0      811-07242         NaN             NaN                   NaN
# 1      028-06746    110814.0       801-24357  549300LNIUIPKJOPIK90
# 2      811-03445         NaN             NaN  549300TXJCENVSEMYP88
#
# No duplicate rows found.
#
# === Data Quality Report: series ===
# Shape: 84 rows x 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   series_id    84 non-null     int64
#  1   form_id      84 non-null     int64
#  2   series_code  84 non-null     object
#  3   series_name  84 non-null     object
#  4   series_lei   84 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 3.4+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    series_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    series_code: 0 / 0.0%
#    series_name: 0 / 0.0%
#    series_lei: 0 / 0.0%
#
# --- Sample Rows ---
#    series_id  form_id series_code  \
# 0          1       13  S000030907
# 1          2       13  S000030908
# 2          3       13  S000070633
#
#                                       series_name            series_lei
# 0     Boston Common ESG Impact International Fund  254900GJOYMZY372YI92
# 1       Boston Common ESG Impact U.S. Equity Fund  254900RNRFP3EEDFE637
# 2  Boston Common ESG Impact Emerging Markets Fund  254900DIAM8IXXG6KE96
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record ===
# Shape: 184253 rows x 15 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184253 entries, 0 to 184252
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   vote_id           184253 non-null  int64
#  1   form_id           184253 non-null  int64
#  2   issuer_name       184253 non-null  object
#  3   cusip             182020 non-null  object
#  4   isin              157924 non-null  object
#  5   figi              156 non-null     object
#  6   meeting_date      183985 non-null  object
#  7   vote_description  184252 non-null  object
#  8   proposed_by       172673 non-null  object
#  9   shares_voted      184253 non-null  float64
#  10  shares_on_loan    184253 non-null  float64
#  11  vote_cast         169506 non-null  object
#  12  vote_cast_shares  169530 non-null  float64
#  13  management_rec    169601 non-null  object
#  14  other_notes       1148 non-null    object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 21.1+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    issuer_name: 0 / 0.0%
#    cusip: 2233 / 1.21%
#    isin: 26329 / 14.29%
#    figi: 184097 / 99.92%
#    meeting_date: 268 / 0.15%
#    vote_description: 1 / 0.0%
#    proposed_by: 11580 / 6.28%
#    shares_voted: 0 / 0.0%
#    shares_on_loan: 0 / 0.0%
#    vote_cast: 14747 / 8.0%
#    vote_cast_shares: 14723 / 7.99%
#    management_rec: 14652 / 7.95%
#    other_notes: 183105 / 99.38%
#
# --- Sample Rows ---
#    vote_id  form_id       issuer_name      cusip isin figi meeting_date  \
# 0        1        1  Paragon 28, Inc.  69913P105  NaN  NaN   2024-05-17
# 1        2        1  Paragon 28, Inc.  69913P105  NaN  NaN   2024-05-17
# 2        3        1    OptiNose, Inc.  68404V100  NaN  NaN   2024-06-06
#
#                                     vote_description proposed_by  \
# 0  Approval, on an advisory basis, of the compens...      ISSUER
# 1  Approval, on an advisory basis, of the frequen...      ISSUER
# 2  To approve, on a non-binding advisory basis, t...      ISSUER
#
#    shares_voted  shares_on_loan vote_cast  vote_cast_shares management_rec  \
# 0    10886145.0             0.0       FOR        10886145.0            FOR
# 1    10886145.0             0.0       FOR        10886145.0            FOR
# 2    14605263.0             0.0       FOR        14605263.0            FOR
#
#   other_notes
# 0         NaN
# 1         NaN
# 2         NaN
#
# No duplicate rows found.
#
# === Data Quality Report: matter_category ===
# Shape: 14 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    14 non-null     int64
#  1   category_type  14 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 352.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    category_id: 0 / 0.0%
#    category_type: 0 / 0.0%
#
# --- Sample Rows ---
#    category_id                 category_type
# 0            1  SECTION 14A SAY-ON-PAY VOTES
# 1            2                  COMPENSATION
# 2            3                         OTHER
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record_category ===
# Shape: 186694 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186694 entries, 0 to 186693
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   vote_id      186694 non-null  int64
#  1   category_id  186694 non-null  int64
# dtypes: int64(2)
# memory usage: 2.8 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    category_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  category_id
# 0        1            1
# 1        2            1
# 2        3            1
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_manager ===
# Shape: 25231 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25231 entries, 0 to 25230
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vote_id     25231 non-null  int64
#  1   manager_id  25231 non-null  int64
# dtypes: int64(2)
# memory usage: 394.4 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    manager_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  manager_id
# 0    45057           6
# 1    45058           6
# 2    45059           6
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_series ===
# Shape: 77424 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77424 entries, 0 to 77423
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vote_id    77424 non-null  int64
#  1   series_id  77418 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 1.2 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    series_id: 6 / 0.01%
#
# --- Sample Rows ---
#    vote_id  series_id
# 0     3625        NaN
# 1     3626        NaN
# 2     3627        NaN
#
# No duplicate rows found.

# %%
#############################################################
#  CELL 4: Additional Cross-Checks (Optional)
#############################################################

# Example cross-check: Ensure that proxy_voting_record_category.vote_id 
# actually exists in proxy_voting_record.vote_id
if dfs["proxy_voting_record"] is not None and not dfs["proxy_voting_record"].empty:
    if dfs["proxy_voting_record_category"] is not None and not dfs["proxy_voting_record_category"].empty:
        # Put them in sets for quick membership test
        valid_vote_ids = set(dfs["proxy_voting_record"]["vote_id"].dropna().unique())
        cat_vote_ids = set(dfs["proxy_voting_record_category"]["vote_id"].dropna().unique())
        
        missing_vote_ids = cat_vote_ids - valid_vote_ids
        if missing_vote_ids:
            print(f"\n[Cross-check] Found {len(missing_vote_ids)} vote_id(s) in proxy_voting_record_category not in proxy_voting_record.")
            print("Missing IDs:", missing_vote_ids)
        else:
            print("\n[Cross-check] All category vote_ids exist in proxy_voting_record!")

# You can similarly check that 'form_id' in institutional_manager, series, etc. 
# actually appears in form_npx.
# Out:
# [Cross-check] All category vote_ids exist in proxy_voting_record!
