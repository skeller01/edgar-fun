# %%
#############################################################
#  CELL 1: Markdown
#############################################################

# Example text for a Markdown cell:
"""
# Data Quality Report for N-PX CSV Outputs

This notebook performs basic data quality checks on the CSV files generated
by the N-PX parsing workflow. We’ll look for:

1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).
2. **Column-level stats**: For each column, how many nulls or missing values?
3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?
4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.

Feel free to add more custom checks, such as:
- Checking valid ranges for numeric columns.
- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).
- Checking that enumerated columns contain only valid values.

Let's begin!
"""
# Out:
# "\n# Data Quality Report for N-PX CSV Outputs\n\nThis notebook performs basic data quality checks on the CSV files generated\nby the N-PX parsing workflow. We’ll look for:\n\n1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).\n2. **Column-level stats**: For each column, how many nulls or missing values?\n3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?\n4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.\n\nFeel free to add more custom checks, such as:\n- Checking valid ranges for numeric columns.\n- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).\n- Checking that enumerated columns contain only valid values.\n\nLet's begin!\n"

# %%
#############################################################
#  CELL 2: Imports & Setup
#############################################################

import os
import pandas as pd

# Point this to the folder where your CSVs are stored
CSV_FOLDER = "output"

# List your tables and corresponding file names
CSV_FILES = {
    "form_npx": "form_npx.csv",
    "institutional_manager": "institutional_manager.csv",
    "series": "series.csv",
    "proxy_voting_record": "proxy_voting_record.csv",
    "matter_category": "matter_category.csv",
    "proxy_voting_record_category": "proxy_voting_record_category.csv",
    "voting_record_manager": "voting_record_manager.csv",
    "voting_record_series": "voting_record_series.csv"
}

# We'll load all of them into a dict of DataFrames.
dfs = {}
for table_name, file_name in CSV_FILES.items():
    path = os.path.join(CSV_FOLDER, file_name)
    if os.path.exists(path):
        df = pd.read_csv(path)
        dfs[table_name] = df
    else:
        print(f"[Warning] {file_name} not found in {CSV_FOLDER}!")
        dfs[table_name] = None

print("DataFrames loaded:")
for k,v in dfs.items():
    if v is not None:
        print(f" - {k}: {len(v)} rows")
    else:
        print(f" - {k}: No data (file missing).")
# Out:
# C:\Users\skell\AppData\Local\Temp\ipykernel_13108\2531012235.py:28: DtypeWarning: Columns (4,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# DataFrames loaded:
#  - form_npx: 200 rows
#  - institutional_manager: 42 rows
#  - series: 204 rows
#  - proxy_voting_record: 318383 rows
#  - matter_category: 16 rows
#  - proxy_voting_record_category: 330998 rows
#  - voting_record_manager: 59364 rows
#  - voting_record_series: 248035 rows

# %%
#############################################################
#  CELL 3: Basic Data Quality Checks
#############################################################

# We’ll create a function to do quick checks on a given DataFrame.
def data_quality_report(df, df_name):
    """
    Print a small summary of data quality for a given DataFrame:
    1. Number of rows & columns
    2. Column data types & non-null counts
    3. Percent missing per column
    4. Sample records (head)
    """
    print(f"\n=== Data Quality Report: {df_name} ===")

    if df is None or df.empty:
        print("No data or empty DataFrame!")
        return

    # 1) Shape
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")

    # 2) Info
    print("\n--- Info ---")
    print(df.info())

    # 3) Missing values
    print("\n--- Missing Values (absolute / percent) ---")
    missing_count = df.isna().sum()
    missing_percent = (df.isna().mean() * 100).round(2)
    for col in df.columns:
        print(f"   {col}: {missing_count[col]} / {missing_percent[col]}%")

    # 4) Quick sample
    print("\n--- Sample Rows ---")
    print(df.head(3))

    # 5) (Optional) Check for duplicates. For small tables, a naive approach:
    #    We won't fix them here, just report.
    dup_count = df.duplicated().sum()
    if dup_count > 0:
        print(f"\n[Warning] {dup_count} duplicate row(s) found in {df_name}.")
    else:
        print("\nNo duplicate rows found.")

    # 6) (Optional) If you have a PK column, check duplicates in that PK:
    # if "form_id" in df.columns:
    #    pk_dup_count = df.duplicated(subset=["form_id"]).sum()
    #    if pk_dup_count > 0:
    #        print(f"[Warning] form_id has {pk_dup_count} duplicates!")
    #    else:
    #        print("form_id column is unique.")


# Now run the data_quality_report for each table
for table_name, df in dfs.items():
    data_quality_report(df, table_name)
# Out:
# === Data Quality Report: form_npx ===
# Shape: 200 rows x 39 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   form_type                       200 non-null    object
#  1   registrant_type                 200 non-null    object
#  2   live_test_flag                  200 non-null    object
#  3   cik                             200 non-null    int64
#  4   phone_number                    200 non-null    object
#  5   investment_company_type         55 non-null     object
#  6   conformed_period                200 non-null    object
#  7   year_or_quarter                 200 non-null    object
#  8   report_calendar_year            199 non-null    float64
#  9   report_quarter_year             1 non-null      float64
#  10  report_type                     200 non-null    object
#  11  confidential_treatment          200 non-null    object
#  12  notice_explanation              0 non-null      float64
#  13  is_notice_report                200 non-null    bool
#  14  is_amendment                    200 non-null    bool
#  15  amendment_no                    0 non-null      float64
#  16  amendment_type                  0 non-null      float64
#  17  reason_for_non_confidentiality  0 non-null      float64
#  18  reporting_crd_number            72 non-null     float64
#  19  reporting_sec_file_number       60 non-null     object
#  20  lei_number                      45 non-null     object
#  21  sec_file_number                 200 non-null    object
#  22  explanatory_choice              200 non-null    object
#  23  explanatory_notes               16 non-null     object
#  24  other_included_managers_count   200 non-null    int64
#  25  reporting_person_name           200 non-null    object
#  26  address_street1                 200 non-null    object
#  27  address_street2                 97 non-null     object
#  28  address_city                    200 non-null    object
#  29  address_state                   200 non-null    object
#  30  address_country                 200 non-null    object
#  31  address_zip                     200 non-null    object
#  32  signatory_name                  200 non-null    object
#  33  signatory_name_printed          200 non-null    object
#  34  signatory_title                 200 non-null    object
#  35  signatory_date                  200 non-null    object
#  36  accession_number                200 non-null    object
#  37  date_filed                      200 non-null    object
#  38  form_id                         200 non-null    int64
# dtypes: bool(2), float64(7), int64(3), object(27)
# memory usage: 58.3+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_type: 0 / 0.0%
#    registrant_type: 0 / 0.0%
#    live_test_flag: 0 / 0.0%
#    cik: 0 / 0.0%
#    phone_number: 0 / 0.0%
#    investment_company_type: 145 / 72.5%
#    conformed_period: 0 / 0.0%
#    year_or_quarter: 0 / 0.0%
#    report_calendar_year: 1 / 0.5%
#    report_quarter_year: 199 / 99.5%
#    report_type: 0 / 0.0%
#    confidential_treatment: 0 / 0.0%
#    notice_explanation: 200 / 100.0%
#    is_notice_report: 0 / 0.0%
#    is_amendment: 0 / 0.0%
#    amendment_no: 200 / 100.0%
#    amendment_type: 200 / 100.0%
#    reason_for_non_confidentiality: 200 / 100.0%
#    reporting_crd_number: 128 / 64.0%
#    reporting_sec_file_number: 140 / 70.0%
#    lei_number: 155 / 77.5%
#    sec_file_number: 0 / 0.0%
#    explanatory_choice: 0 / 0.0%
#    explanatory_notes: 184 / 92.0%
#    other_included_managers_count: 0 / 0.0%
#    reporting_person_name: 0 / 0.0%
#    address_street1: 0 / 0.0%
#    address_street2: 103 / 51.5%
#    address_city: 0 / 0.0%
#    address_state: 0 / 0.0%
#    address_country: 0 / 0.0%
#    address_zip: 0 / 0.0%
#    signatory_name: 0 / 0.0%
#    signatory_name_printed: 0 / 0.0%
#    signatory_title: 0 / 0.0%
#    signatory_date: 0 / 0.0%
#    accession_number: 0 / 0.0%
#    date_filed: 0 / 0.0%
#    form_id: 0 / 0.0%
#
# --- Sample Rows ---
#   form_type registrant_type live_test_flag      cik  phone_number  \
# 0      N-PX              IM           LIVE  1536924    6157623163
# 1      N-PX              IM           LIVE  1896711    8476561111
# 2      N-PX              IM           LIVE  1588456  239-254-2500
#
#   investment_company_type conformed_period year_or_quarter  \
# 0                     NaN       2024-06-30            YEAR
# 1                     NaN       2024-06-30            YEAR
# 2                     NaN       2024-06-30            YEAR
#
#    report_calendar_year  report_quarter_year  ... address_state  \
# 0                2024.0                  NaN  ...            TN
# 1                2024.0                  NaN  ...            IL
# 2                2024.0                  NaN  ...            FL
#
#   address_country  address_zip   signatory_name  signatory_name_printed  \
# 0              TN        37027      Tracey Hill             Tracey Hill
# 1              IL        60062  Walter M. Kelly         Walter M. Kelly
# 2              FL        34108   Chad D. Atkins          Chad D. Atkins
#
#             signatory_title  signatory_date      accession_number  date_filed  \
# 0  Chief Compliance Officer      2024-07-01  0001536924-24-000004  2024-07-01
# 1  Chief Compliance Officer      2024-07-02  0001896711-24-000005  2024-07-03
# 2         President and CCO      2024-07-12  0001214659-24-012298  2024-07-12
#
#   form_id
# 0       1
# 1       2
# 2       3
#
# [3 rows x 39 columns]
#
# No duplicate rows found.
#
# === Data Quality Report: institutional_manager ===
# Shape: 42 rows x 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manager_id       42 non-null     int64
#  1   form_id          42 non-null     int64
#  2   serial_no        35 non-null     float64
#  3   name             35 non-null     object
#  4   form13f_number   35 non-null     object
#  5   crd_number       15 non-null     float64
#  6   sec_file_number  14 non-null     object
#  7   lei_number       15 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.8+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    manager_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    serial_no: 7 / 16.67%
#    name: 7 / 16.67%
#    form13f_number: 7 / 16.67%
#    crd_number: 27 / 64.29%
#    sec_file_number: 28 / 66.67%
#    lei_number: 27 / 64.29%
#
# --- Sample Rows ---
#    manager_id  form_id  serial_no                              name  \
# 0           1       35      801.0                 William Oldfather
# 1           2       60        1.0           Citizens  Northern Bank
# 2           3       71        2.0  Loomis Sayles Trust Company, LLC
#
#   form13f_number  crd_number sec_file_number            lei_number
# 0      028-19711    112505.0             NaN                   NaN
# 1       28-14473         NaN             NaN                   NaN
# 2      028-13087         NaN             NaN  549300DZZSM2BX1KLV04
#
# No duplicate rows found.
#
# === Data Quality Report: series ===
# Shape: 204 rows x 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   series_id    204 non-null    int64
#  1   form_id      204 non-null    int64
#  2   series_code  204 non-null    object
#  3   series_name  204 non-null    object
#  4   series_lei   204 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 8.1+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    series_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    series_code: 0 / 0.0%
#    series_name: 0 / 0.0%
#    series_lei: 0 / 0.0%
#
# --- Sample Rows ---
#    series_id  form_id series_code  \
# 0          1       11  S000059809
# 1          2       24  S000067433
# 2          3       24  S000063455
#
#                                          series_name            series_lei
# 0  Dreyfus Treasury and Agency Liquidity Money Ma...  549300PYJOW0O9S0U493
# 1           Acclivity Broad Equity Multi-Style Fund*  00000000000000000000
# 2                   Acclivity Small Cap Growth Fund*  00000000000000000000
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record ===
# Shape: 318383 rows x 15 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318383 entries, 0 to 318382
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   form_id           318383 non-null  int64
#  1   issuer_name       318383 non-null  object
#  2   cusip             284622 non-null  object
#  3   isin              263710 non-null  object
#  4   figi              306 non-null     object
#  5   meeting_date      318374 non-null  object
#  6   vote_description  318383 non-null  object
#  7   proposed_by       285049 non-null  object
#  8   shares_voted      318382 non-null  float64
#  9   shares_on_loan    318382 non-null  float64
#  10  vote_cast         286517 non-null  object
#  11  vote_cast_shares  286716 non-null  float64
#  12  management_rec    286718 non-null  object
#  13  other_notes       296 non-null     object
#  14  vote_id           318383 non-null  int64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 36.4+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_id: 0 / 0.0%
#    issuer_name: 0 / 0.0%
#    cusip: 33761 / 10.6%
#    isin: 54673 / 17.17%
#    figi: 318077 / 99.9%
#    meeting_date: 9 / 0.0%
#    vote_description: 0 / 0.0%
#    proposed_by: 33334 / 10.47%
#    shares_voted: 1 / 0.0%
#    shares_on_loan: 1 / 0.0%
#    vote_cast: 31866 / 10.01%
#    vote_cast_shares: 31667 / 9.95%
#    management_rec: 31665 / 9.95%
#    other_notes: 318087 / 99.91%
#    vote_id: 0 / 0.0%
#
# --- Sample Rows ---
#    form_id              issuer_name      cusip          isin figi  \
# 0        3  CRA International, Inc.  12618T105  US12618T1051  NaN
# 1        3  CRA International, Inc.  12618T105  US12618T1051  NaN
# 2        3         PowerFleet, Inc.  73931J109  US73931J1097  NaN
#
#   meeting_date                                   vote_description proposed_by  \
# 0   2023-07-13  To approve, on an advisory basis, the compensa...         NaN
# 1   2023-07-13  To approve, on an advisory basis, the preferre...         NaN
# 2   2023-07-20  Advisory approval of the Company's executive c...         NaN
#
#    shares_voted  shares_on_loan vote_cast  vote_cast_shares management_rec  \
# 0       68507.0             0.0       FOR           68507.0            FOR
# 1       68507.0             0.0    1 YEAR           68507.0            FOR
# 2     4255350.0             0.0       FOR         4255350.0            FOR
#
#   other_notes  vote_id
# 0         NaN        1
# 1         NaN        2
# 2         NaN        3
#
# No duplicate rows found.
#
# === Data Quality Report: matter_category ===
# Shape: 16 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    16 non-null     int64
#  1   category_type  16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    category_id: 0 / 0.0%
#    category_type: 0 / 0.0%
#
# --- Sample Rows ---
#    category_id                 category_type
# 0            1  SECTION 14A SAY-ON-PAY VOTES
# 1            2                         OTHER
# 2            3                  COMPENSATION
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record_category ===
# Shape: 330998 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330998 entries, 0 to 330997
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   vote_id      330998 non-null  int64
#  1   category_id  330998 non-null  int64
# dtypes: int64(2)
# memory usage: 5.1 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    category_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  category_id
# 0        1            1
# 1        2            1
# 2        3            1
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_manager ===
# Shape: 59364 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59364 entries, 0 to 59363
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vote_id     59364 non-null  int64
#  1   manager_id  59364 non-null  int64
# dtypes: int64(2)
# memory usage: 927.7 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    manager_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  manager_id
# 0        1           1
# 1        2           2
# 2        3           3
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_series ===
# Shape: 248035 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248035 entries, 0 to 248034
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   vote_id    248035 non-null  int64
#  1   series_id  248035 non-null  int64
# dtypes: int64(2)
# memory usage: 3.8 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    series_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  series_id
# 0        1          1
# 1        2          2
# 2        3          3
#
# No duplicate rows found.

# %%
#############################################################
#  CELL 4: Additional Cross-Checks (Optional)
#############################################################

# Example cross-check: Ensure that proxy_voting_record_category.vote_id 
# actually exists in proxy_voting_record.vote_id
if dfs["proxy_voting_record"] is not None and not dfs["proxy_voting_record"].empty:
    if dfs["proxy_voting_record_category"] is not None and not dfs["proxy_voting_record_category"].empty:
        # Put them in sets for quick membership test
        valid_vote_ids = set(dfs["proxy_voting_record"]["vote_id"].dropna().unique())
        cat_vote_ids = set(dfs["proxy_voting_record_category"]["vote_id"].dropna().unique())
        
        missing_vote_ids = cat_vote_ids - valid_vote_ids
        if missing_vote_ids:
            print(f"\n[Cross-check] Found {len(missing_vote_ids)} vote_id(s) in proxy_voting_record_category not in proxy_voting_record.")
            print("Missing IDs:", missing_vote_ids)
        else:
            print("\n[Cross-check] All category vote_ids exist in proxy_voting_record!")

# You can similarly check that 'form_id' in institutional_manager, series, etc. 
# actually appears in form_npx.
# Out:
# [Cross-check] All category vote_ids exist in proxy_voting_record!
