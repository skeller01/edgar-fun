# %%
#############################################################
#  CELL 1: Markdown
#############################################################

# Example text for a Markdown cell:
"""
# Data Quality Report for N-PX CSV Outputs

This notebook performs basic data quality checks on the CSV files generated
by the N-PX parsing workflow. We’ll look for:

1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).
2. **Column-level stats**: For each column, how many nulls or missing values?
3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?
4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.

Feel free to add more custom checks, such as:
- Checking valid ranges for numeric columns.
- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).
- Checking that enumerated columns contain only valid values.

Let's begin!
"""
# Out:
# "\n# Data Quality Report for N-PX CSV Outputs\n\nThis notebook performs basic data quality checks on the CSV files generated\nby the N-PX parsing workflow. We’ll look for:\n\n1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).\n2. **Column-level stats**: For each column, how many nulls or missing values?\n3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?\n4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.\n\nFeel free to add more custom checks, such as:\n- Checking valid ranges for numeric columns.\n- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).\n- Checking that enumerated columns contain only valid values.\n\nLet's begin!\n"

# %%
#############################################################
#  CELL 2: Imports & Setup
#############################################################

import os
import pandas as pd

# Point this to the folder where your CSVs are stored
CSV_FOLDER = "output"

# List your tables and corresponding file names
CSV_FILES = {
    "form_npx": "form_npx.csv",
    "institutional_manager": "institutional_manager.csv",
    "series": "series.csv",
    "proxy_voting_record": "proxy_voting_record.csv",
    "matter_category": "matter_category.csv",
    "proxy_voting_record_category": "proxy_voting_record_category.csv",
    "voting_record_manager": "voting_record_manager.csv",
    "voting_record_series": "voting_record_series.csv"
}

# We'll load all of them into a dict of DataFrames.
dfs = {}
for table_name, file_name in CSV_FILES.items():
    path = os.path.join(CSV_FOLDER, file_name)
    if os.path.exists(path):
        df = pd.read_csv(path)
        dfs[table_name] = df
    else:
        print(f"[Warning] {file_name} not found in {CSV_FOLDER}!")
        dfs[table_name] = None

print("DataFrames loaded:")
for k,v in dfs.items():
    if v is not None:
        print(f" - {k}: {len(v)} rows")
    else:
        print(f" - {k}: No data (file missing).")
# Out:
# DataFrames loaded:
#  - form_npx: 97 rows
#  - institutional_manager: 19 rows
#  - series: 34 rows
#  - proxy_voting_record: 56865 rows
#  - matter_category: 14 rows
#  - proxy_voting_record_category: 57874 rows
#  - voting_record_manager: 7077 rows
#  - voting_record_series: 34336 rows

# %%
#############################################################
#  CELL 3: Basic Data Quality Checks
#############################################################

# We’ll create a function to do quick checks on a given DataFrame.
def data_quality_report(df, df_name):
    """
    Print a small summary of data quality for a given DataFrame:
    1. Number of rows & columns
    2. Column data types & non-null counts
    3. Percent missing per column
    4. Sample records (head)
    """
    print(f"\n=== Data Quality Report: {df_name} ===")

    if df is None or df.empty:
        print("No data or empty DataFrame!")
        return

    # 1) Shape
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")

    # 2) Info
    print("\n--- Info ---")
    print(df.info())

    # 3) Missing values
    print("\n--- Missing Values (absolute / percent) ---")
    missing_count = df.isna().sum()
    missing_percent = (df.isna().mean() * 100).round(2)
    for col in df.columns:
        print(f"   {col}: {missing_count[col]} / {missing_percent[col]}%")

    # 4) Quick sample
    print("\n--- Sample Rows ---")
    print(df.head(3))

    # 5) (Optional) Check for duplicates. For small tables, a naive approach:
    #    We won't fix them here, just report.
    dup_count = df.duplicated().sum()
    if dup_count > 0:
        print(f"\n[Warning] {dup_count} duplicate row(s) found in {df_name}.")
    else:
        print("\nNo duplicate rows found.")

    # 6) (Optional) If you have a PK column, check duplicates in that PK:
    # if "form_id" in df.columns:
    #    pk_dup_count = df.duplicated(subset=["form_id"]).sum()
    #    if pk_dup_count > 0:
    #        print(f"[Warning] form_id has {pk_dup_count} duplicates!")
    #    else:
    #        print("form_id column is unique.")


# Now run the data_quality_report for each table
for table_name, df in dfs.items():
    data_quality_report(df, table_name)
# Out:
# === Data Quality Report: form_npx ===
# Shape: 97 rows x 32 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   form_id                        97 non-null     int64
#  1   reporting_person_name          97 non-null     object
#  2   phone_number                   97 non-null     object
#  3   address_street1                97 non-null     object
#  4   address_street2                46 non-null     object
#  5   address_city                   97 non-null     object
#  6   address_state                  97 non-null     object
#  7   address_zip                    97 non-null     object
#  8   accession_number               97 non-null     object
#  9   cik                            97 non-null     int64
#  10  conformed_period               97 non-null     object
#  11  date_filed                     97 non-null     object
#  12  report_type                    97 non-null     object
#  13  form_type                      97 non-null     object
#  14  sec_file_number                97 non-null     object
#  15  crd_number                     37 non-null     float64
#  16  sec_file_number_other          31 non-null     object
#  17  lei_number                     19 non-null     object
#  18  investment_company_type        28 non-null     object
#  19  confidential_treatment         97 non-null     object
#  20  is_notice_report               97 non-null     bool
#  21  explanatory_choice             97 non-null     object
#  22  other_included_managers_count  97 non-null     int64
#  23  series_count                   97 non-null     int64
#  24  is_amendment                   97 non-null     bool
#  25  amendment_no                   1 non-null      float64
#  26  amendment_type                 1 non-null      object
#  27  notice_explanation             44 non-null     object
#  28  signatory_name                 97 non-null     object
#  29  signatory_name_printed         97 non-null     object
#  30  signatory_title                97 non-null     object
#  31  signatory_date                 97 non-null     object
# dtypes: bool(2), float64(2), int64(4), object(24)
# memory usage: 23.0+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_id: 0 / 0.0%
#    reporting_person_name: 0 / 0.0%
#    phone_number: 0 / 0.0%
#    address_street1: 0 / 0.0%
#    address_street2: 51 / 52.58%
#    address_city: 0 / 0.0%
#    address_state: 0 / 0.0%
#    address_zip: 0 / 0.0%
#    accession_number: 0 / 0.0%
#    cik: 0 / 0.0%
#    conformed_period: 0 / 0.0%
#    date_filed: 0 / 0.0%
#    report_type: 0 / 0.0%
#    form_type: 0 / 0.0%
#    sec_file_number: 0 / 0.0%
#    crd_number: 60 / 61.86%
#    sec_file_number_other: 66 / 68.04%
#    lei_number: 78 / 80.41%
#    investment_company_type: 69 / 71.13%
#    confidential_treatment: 0 / 0.0%
#    is_notice_report: 0 / 0.0%
#    explanatory_choice: 0 / 0.0%
#    other_included_managers_count: 0 / 0.0%
#    series_count: 0 / 0.0%
#    is_amendment: 0 / 0.0%
#    amendment_no: 96 / 98.97%
#    amendment_type: 96 / 98.97%
#    notice_explanation: 53 / 54.64%
#    signatory_name: 0 / 0.0%
#    signatory_name_printed: 0 / 0.0%
#    signatory_title: 0 / 0.0%
#    signatory_date: 0 / 0.0%
#
# --- Sample Rows ---
#    form_id   reporting_person_name  phone_number          address_street1  \
# 0        1  SBB Research Group LLC    8476561111         450 SKOKIE BLVD.
# 1        2               SFMG, LLC    9729606460      7800 DALLAS PARKWAY
# 2        3   West Oak Capital, LLC  208 722-2280  1028 S. Bridgeway Place
#
#   address_street2 address_city address_state address_zip  \
# 0    BUILDING 600   NORTHBROOK            IL       60062
# 1       SUITE 350        PLANO            TX       75024
# 2      Suite 120B        Eagle            ID       83616
#
#        accession_number      cik  ... other_included_managers_count  \
# 0  0001896711-24-000005  1896711  ...                             0
# 1  0001512026-24-000004  1512026  ...                             0
# 2  0001140361-24-033397  1387399  ...                             1
#
#   series_count is_amendment amendment_no amendment_type  \
# 0            0        False          NaN            NaN
# 1            0        False          NaN            NaN
# 2            0        False          NaN            NaN
#
#                          notice_explanation    signatory_name  \
# 0  REPORTING PERSON DID NOT EXERCISE VOTING   Walter M. Kelly
# 1   REPORTING PERSON HAS POLICY TO NOT VOTE   Crystal Billing
# 2                                       NaN  /s/ Byron Snider
#
#   signatory_name_printed           signatory_title signatory_date
# 0        Walter M. Kelly  Chief Compliance Officer     2024-07-02
# 1        Crystal Billing                       CCO     2024-07-01
# 2       /s/ Byron Snider                 President     2024-07-08
#
# [3 rows x 32 columns]
#
# No duplicate rows found.
#
# === Data Quality Report: institutional_manager ===
# Shape: 19 rows x 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manager_id       19 non-null     int64
#  1   form_id          19 non-null     int64
#  2   serial_no        14 non-null     float64
#  3   name             19 non-null     object
#  4   form13f_number   18 non-null     object
#  5   crd_number       7 non-null      float64
#  6   sec_file_number  7 non-null      object
#  7   lei_number       7 non-null      object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.3+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    manager_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    serial_no: 5 / 26.32%
#    name: 0 / 0.0%
#    form13f_number: 1 / 5.26%
#    crd_number: 12 / 63.16%
#    sec_file_number: 12 / 63.16%
#    lei_number: 12 / 63.16%
#
# --- Sample Rows ---
#    manager_id  form_id  serial_no                     name form13f_number  \
# 0           1        3        1.0  Institutional Manager 1            NaN
# 1           2       33        1.0               BNY MELLON      028-12592
# 2           3       37       19.0  BlackRock Advisors, LLC      028-04295
#
#    crd_number sec_file_number            lei_number
# 0    128473.0       801-62367                   NaN
# 1         NaN             NaN                   NaN
# 2    106614.0       801-47710  5493001LN9MRM6A35J74
#
# No duplicate rows found.
#
# === Data Quality Report: series ===
# Shape: 34 rows x 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   series_id    34 non-null     int64
#  1   form_id      34 non-null     int64
#  2   series_code  34 non-null     object
#  3   series_name  34 non-null     object
#  4   series_lei   34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    series_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    series_code: 0 / 0.0%
#    series_name: 0 / 0.0%
#    series_lei: 0 / 0.0%
#
# --- Sample Rows ---
#    series_id  form_id series_code  \
# 0          1       11  S000062392
# 1          2       24  S000001230
# 2          3       27  S000067573
#
#                                    series_name            series_lei
# 0                                 Cargile Fund  549300DBZNEXVZ7EXT45
# 1  Cohen  Steers Alternative Income Fund, Inc.  549300INNVESYCL5LK20
# 2                                One Rock Fund  549300WX4P7FVPSA2Y70
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record ===
# Shape: 56865 rows x 15 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56865 entries, 0 to 56864
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   vote_id           56865 non-null  int64
#  1   form_id           56865 non-null  int64
#  2   issuer_name       56865 non-null  object
#  3   cusip             46087 non-null  object
#  4   isin              42847 non-null  object
#  5   figi              0 non-null      float64
#  6   meeting_date      56865 non-null  object
#  7   vote_description  56865 non-null  object
#  8   proposed_by       41750 non-null  object
#  9   shares_voted      56864 non-null  float64
#  10  shares_on_loan    56865 non-null  float64
#  11  vote_cast         56187 non-null  object
#  12  vote_cast_shares  56189 non-null  float64
#  13  management_rec    56189 non-null  object
#  14  other_notes       23 non-null     object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 6.5+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    issuer_name: 0 / 0.0%
#    cusip: 10778 / 18.95%
#    isin: 14018 / 24.65%
#    figi: 56865 / 100.0%
#    meeting_date: 0 / 0.0%
#    vote_description: 0 / 0.0%
#    proposed_by: 15115 / 26.58%
#    shares_voted: 1 / 0.0%
#    shares_on_loan: 0 / 0.0%
#    vote_cast: 678 / 1.19%
#    vote_cast_shares: 676 / 1.19%
#    management_rec: 676 / 1.19%
#    other_notes: 56842 / 99.96%
#
# --- Sample Rows ---
#    vote_id  form_id                 issuer_name      cusip isin  figi  \
# 0        1        3          BLACK KNIGHT, INC.  09215C105  NaN   NaN
# 1        2        3     FG ANNUITIES  LIFE INC.  30190A104  NaN   NaN
# 2        3        3  CHARGEPOINT HOLDINGS, INC.  15961R105  NaN   NaN
#
#   meeting_date                                   vote_description proposed_by  \
# 0   2023-07-12  Approval of a non-binding advisory resolution ...         NaN
# 1   2023-07-12  Approval of a non-binding advisory resolution ...         NaN
# 2   2023-07-18  The advisory approval of the compensation of o...         NaN
#
#    shares_voted  shares_on_loan vote_cast  vote_cast_shares management_rec  \
# 0       10792.0             0.0       FOR           10792.0            FOR
# 1        2393.0             0.0       FOR            2393.0            FOR
# 2         100.0             0.0       FOR             100.0            FOR
#
#   other_notes
# 0         NaN
# 1         NaN
# 2         NaN
#
# No duplicate rows found.
#
# === Data Quality Report: matter_category ===
# Shape: 14 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    14 non-null     int64
#  1   category_type  14 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 352.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    category_id: 0 / 0.0%
#    category_type: 0 / 0.0%
#
# --- Sample Rows ---
#    category_id                 category_type
# 0            1  SECTION 14A SAY-ON-PAY VOTES
# 1            2          CORPORATE GOVERNANCE
# 2            3                         OTHER
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record_category ===
# Shape: 57874 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57874 entries, 0 to 57873
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vote_id      57874 non-null  int64
#  1   category_id  57874 non-null  int64
# dtypes: int64(2)
# memory usage: 904.4 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    category_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  category_id
# 0        1            1
# 1        2            1
# 2        3            1
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_manager ===
# Shape: 7077 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7077 entries, 0 to 7076
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vote_id     7077 non-null   int64
#  1   manager_id  3207 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 110.7 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    manager_id: 3870 / 54.68%
#
# --- Sample Rows ---
#    vote_id  manager_id
# 0     3089         NaN
# 1     3090         NaN
# 2     3091         NaN
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_series ===
# Shape: 34336 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34336 entries, 0 to 34335
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   vote_id    34336 non-null  int64
#  1   series_id  34336 non-null  int64
# dtypes: int64(2)
# memory usage: 536.6 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    series_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  series_id
# 0     7176          2
# 1     7177          2
# 2     7178          2
#
# No duplicate rows found.

# %%
#############################################################
#  CELL 4: Additional Cross-Checks (Optional)
#############################################################

# Example cross-check: Ensure that proxy_voting_record_category.vote_id 
# actually exists in proxy_voting_record.vote_id
if dfs["proxy_voting_record"] is not None and not dfs["proxy_voting_record"].empty:
    if dfs["proxy_voting_record_category"] is not None and not dfs["proxy_voting_record_category"].empty:
        # Put them in sets for quick membership test
        valid_vote_ids = set(dfs["proxy_voting_record"]["vote_id"].dropna().unique())
        cat_vote_ids = set(dfs["proxy_voting_record_category"]["vote_id"].dropna().unique())
        
        missing_vote_ids = cat_vote_ids - valid_vote_ids
        if missing_vote_ids:
            print(f"\n[Cross-check] Found {len(missing_vote_ids)} vote_id(s) in proxy_voting_record_category not in proxy_voting_record.")
            print("Missing IDs:", missing_vote_ids)
        else:
            print("\n[Cross-check] All category vote_ids exist in proxy_voting_record!")

# You can similarly check that 'form_id' in institutional_manager, series, etc. 
# actually appears in form_npx.
# Out:
# [Cross-check] All category vote_ids exist in proxy_voting_record!
