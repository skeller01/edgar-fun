# %%
#############################################################
#  CELL 1: Markdown
#############################################################

# Example text for a Markdown cell:
"""
# Data Quality Report for N-PX CSV Outputs

This notebook performs basic data quality checks on the CSV files generated
by the N-PX parsing workflow. We’ll look for:

1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).
2. **Column-level stats**: For each column, how many nulls or missing values?
3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?
4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.

Feel free to add more custom checks, such as:
- Checking valid ranges for numeric columns.
- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).
- Checking that enumerated columns contain only valid values.

Let's begin!
"""
# Out:
# "\n# Data Quality Report for N-PX CSV Outputs\n\nThis notebook performs basic data quality checks on the CSV files generated\nby the N-PX parsing workflow. We’ll look for:\n\n1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).\n2. **Column-level stats**: For each column, how many nulls or missing values?\n3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?\n4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.\n\nFeel free to add more custom checks, such as:\n- Checking valid ranges for numeric columns.\n- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).\n- Checking that enumerated columns contain only valid values.\n\nLet's begin!\n"

# %%
#############################################################
#  CELL 2: Imports & Setup
#############################################################

import os
import pandas as pd

# Point this to the folder where your CSVs are stored
CSV_FOLDER = "output"

# List your tables and corresponding file names
CSV_FILES = {
    "form_npx": "form_npx.csv",
    "institutional_manager": "institutional_manager.csv",
    "series": "series.csv",
    "proxy_voting_record": "proxy_voting_record.csv",
    "matter_category": "matter_category.csv",
    "proxy_voting_record_category": "proxy_voting_record_category.csv",
    "voting_record_manager": "voting_record_manager.csv",
    "voting_record_series": "voting_record_series.csv"
}

# We'll load all of them into a dict of DataFrames.
dfs = {}
for table_name, file_name in CSV_FILES.items():
    path = os.path.join(CSV_FOLDER, file_name)
    if os.path.exists(path):
        df = pd.read_csv(path)
        dfs[table_name] = df
    else:
        print(f"[Warning] {file_name} not found in {CSV_FOLDER}!")
        dfs[table_name] = None

print("DataFrames loaded:")
for k,v in dfs.items():
    if v is not None:
        print(f" - {k}: {len(v)} rows")
    else:
        print(f" - {k}: No data (file missing).")
# Out:
# DataFrames loaded:
#  - form_npx: 25 rows
#  - institutional_manager: 4 rows
#  - series: 44 rows
#  - proxy_voting_record: 115047 rows
#  - matter_category: 15 rows
#  - proxy_voting_record_category: 120051 rows
#  - voting_record_manager: 1558 rows
#  - voting_record_series: 113332 rows

# %%
#############################################################
#  CELL 3: Basic Data Quality Checks
#############################################################

# We’ll create a function to do quick checks on a given DataFrame.
def data_quality_report(df, df_name):
    """
    Print a small summary of data quality for a given DataFrame:
    1. Number of rows & columns
    2. Column data types & non-null counts
    3. Percent missing per column
    4. Sample records (head)
    """
    print(f"\n=== Data Quality Report: {df_name} ===")

    if df is None or df.empty:
        print("No data or empty DataFrame!")
        return

    # 1) Shape
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")

    # 2) Info
    print("\n--- Info ---")
    print(df.info())

    # 3) Missing values
    print("\n--- Missing Values (absolute / percent) ---")
    missing_count = df.isna().sum()
    missing_percent = (df.isna().mean() * 100).round(2)
    for col in df.columns:
        print(f"   {col}: {missing_count[col]} / {missing_percent[col]}%")

    # 4) Quick sample
    print("\n--- Sample Rows ---")
    print(df.head(3))

    # 5) (Optional) Check for duplicates. For small tables, a naive approach:
    #    We won't fix them here, just report.
    dup_count = df.duplicated().sum()
    if dup_count > 0:
        print(f"\n[Warning] {dup_count} duplicate row(s) found in {df_name}.")
    else:
        print("\nNo duplicate rows found.")

    # 6) (Optional) If you have a PK column, check duplicates in that PK:
    # if "form_id" in df.columns:
    #    pk_dup_count = df.duplicated(subset=["form_id"]).sum()
    #    if pk_dup_count > 0:
    #        print(f"[Warning] form_id has {pk_dup_count} duplicates!")
    #    else:
    #        print("form_id column is unique.")


# Now run the data_quality_report for each table
for table_name, df in dfs.items():
    data_quality_report(df, table_name)
# Out:
# === Data Quality Report: form_npx ===
# Shape: 25 rows x 31 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   form_type                      25 non-null     object
#  1   phone_number                   25 non-null     object
#  2   accession_number               0 non-null      float64
#  3   cik                            25 non-null     int64
#  4   conformed_period               25 non-null     object
#  5   date_filed                     0 non-null      float64
#  6   investment_company_type        10 non-null     object
#  7   report_type                    25 non-null     object
#  8   confidential_treatment         25 non-null     object
#  9   is_notice_report               25 non-null     bool
#  10  explanatory_choice             25 non-null     object
#  11  reporting_person_name          25 non-null     object
#  12  address_street1                25 non-null     object
#  13  address_street2                14 non-null     object
#  14  address_city                   25 non-null     object
#  15  address_state                  25 non-null     object
#  16  address_zip                    25 non-null     int64
#  17  other_included_managers_count  25 non-null     int64
#  18  is_amendment                   25 non-null     bool
#  19  amendment_no                   0 non-null      float64
#  20  amendment_type                 0 non-null      float64
#  21  notice_explanation             0 non-null      float64
#  22  signatory_name                 25 non-null     object
#  23  signatory_name_printed         25 non-null     object
#  24  signatory_title                25 non-null     object
#  25  signatory_date                 25 non-null     object
#  26  sec_file_number                0 non-null      float64
#  27  crd_number                     0 non-null      float64
#  28  sec_file_number_other          0 non-null      float64
#  29  lei_number                     0 non-null      float64
#  30  form_id                        25 non-null     int64
# dtypes: bool(2), float64(9), int64(4), object(16)
# memory usage: 5.8+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_type: 0 / 0.0%
#    phone_number: 0 / 0.0%
#    accession_number: 25 / 100.0%
#    cik: 0 / 0.0%
#    conformed_period: 0 / 0.0%
#    date_filed: 25 / 100.0%
#    investment_company_type: 15 / 60.0%
#    report_type: 0 / 0.0%
#    confidential_treatment: 0 / 0.0%
#    is_notice_report: 0 / 0.0%
#    explanatory_choice: 0 / 0.0%
#    reporting_person_name: 0 / 0.0%
#    address_street1: 0 / 0.0%
#    address_street2: 11 / 44.0%
#    address_city: 0 / 0.0%
#    address_state: 0 / 0.0%
#    address_zip: 0 / 0.0%
#    other_included_managers_count: 0 / 0.0%
#    is_amendment: 0 / 0.0%
#    amendment_no: 25 / 100.0%
#    amendment_type: 25 / 100.0%
#    notice_explanation: 25 / 100.0%
#    signatory_name: 0 / 0.0%
#    signatory_name_printed: 0 / 0.0%
#    signatory_title: 0 / 0.0%
#    signatory_date: 0 / 0.0%
#    sec_file_number: 25 / 100.0%
#    crd_number: 25 / 100.0%
#    sec_file_number_other: 25 / 100.0%
#    lei_number: 25 / 100.0%
#    form_id: 0 / 0.0%
#
# --- Sample Rows ---
#   form_type  phone_number  accession_number      cik conformed_period  \
# 0      N-PX  336-725-5579               NaN  1639997       2024-06-30
# 1      N-PX  207-985-8585               NaN  1915315       2024-06-30
# 2      N-PX  540-989-3030               NaN  1694896       2024-06-30
#
#    date_filed investment_company_type                          report_type  \
# 0         NaN                     NaN  INSTITUTIONAL MANAGER NOTICE REPORT
# 1         NaN                     NaN  INSTITUTIONAL MANAGER NOTICE REPORT
# 2         NaN                     NaN  INSTITUTIONAL MANAGER NOTICE REPORT
#
#   confidential_treatment  is_notice_report  ... notice_explanation  \
# 0                      N              True  ...                NaN
# 1                      N              True  ...                NaN
# 2                      N              True  ...                NaN
#
#           signatory_name signatory_name_printed  \
# 0         Harry Shertzer         Harry Shertzer
# 1            Justin Happ            Justin Happ
# 2  Robert D. Benson, Jr.  Robert D. Benson, Jr.
#
#                               signatory_title signatory_date sec_file_number  \
# 0  Portfolio Manager/Chief Compliance Officer     2024-07-15             NaN
# 1                          Compliance Manager     2024-07-17             NaN
# 2                                   President     2024-08-01             NaN
#
#    crd_number  sec_file_number_other  lei_number  form_id
# 0         NaN                    NaN         NaN        1
# 1         NaN                    NaN         NaN        2
# 2         NaN                    NaN         NaN        3
#
# [3 rows x 31 columns]
#
# No duplicate rows found.
#
# === Data Quality Report: institutional_manager ===
# Shape: 4 rows x 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manager_id       4 non-null      int64
#  1   form_id          4 non-null      int64
#  2   serial_no        3 non-null      float64
#  3   name             3 non-null      object
#  4   form13f_number   3 non-null      object
#  5   crd_number       0 non-null      float64
#  6   sec_file_number  0 non-null      float64
#  7   lei_number       1 non-null      object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 384.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    manager_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    serial_no: 1 / 25.0%
#    name: 1 / 25.0%
#    form13f_number: 1 / 25.0%
#    crd_number: 4 / 100.0%
#    sec_file_number: 4 / 100.0%
#    lei_number: 3 / 75.0%
#
# --- Sample Rows ---
#    manager_id  form_id  serial_no                               name  \
# 0           1       18        1.0  Wellington Management Company LLP
# 1           2       20        NaN                                NaN
# 2           3       21        1.0              Tidal Investments LLC
#
#   form13f_number  crd_number  sec_file_number            lei_number
# 0      028-16899         NaN              NaN                   NaN
# 1            NaN         NaN              NaN                   NaN
# 2      028-19397         NaN              NaN  254900SIR1F8HDIXDL70
#
# No duplicate rows found.
#
# === Data Quality Report: series ===
# Shape: 44 rows x 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   series_id    44 non-null     int64
#  1   form_id      44 non-null     int64
#  2   series_code  44 non-null     object
#  3   series_name  44 non-null     object
#  4   series_lei   44 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.8+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    series_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    series_code: 0 / 0.0%
#    series_name: 0 / 0.0%
#    series_lei: 0 / 0.0%
#
# --- Sample Rows ---
#    series_id  form_id series_code                               series_name  \
# 0          1        8  S000079052       Altegris Crabel Multi-Strategy Fund
# 1          2        8  S000034148  Altegris Futures Evolution Strategy Fund
# 2          3        8  S000030708              Beech Hill Total Return Fund
#
#              series_lei
# 0  549300NCUJCIKLMSHE04
# 1  549300QS50K1YX3VUM61
# 2  54930008EEZ1S4P4XT27
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record ===
# Shape: 115047 rows x 15 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115047 entries, 0 to 115046
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   form_id           115047 non-null  int64
#  1   issuer_name       115047 non-null  object
#  2   cusip             110882 non-null  object
#  3   isin              107574 non-null  object
#  4   figi              4 non-null       object
#  5   meeting_date      112184 non-null  object
#  6   vote_description  115047 non-null  object
#  7   proposed_by       113521 non-null  object
#  8   shares_voted      115046 non-null  float64
#  9   shares_on_loan    115046 non-null  float64
#  10  vote_cast         114391 non-null  object
#  11  vote_cast_shares  114389 non-null  float64
#  12  management_rec    114391 non-null  object
#  13  other_notes       133 non-null     object
#  14  vote_id           115047 non-null  int64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 13.2+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_id: 0 / 0.0%
#    issuer_name: 0 / 0.0%
#    cusip: 4165 / 3.62%
#    isin: 7473 / 6.5%
#    figi: 115043 / 100.0%
#    meeting_date: 2863 / 2.49%
#    vote_description: 0 / 0.0%
#    proposed_by: 1526 / 1.33%
#    shares_voted: 1 / 0.0%
#    shares_on_loan: 1 / 0.0%
#    vote_cast: 656 / 0.57%
#    vote_cast_shares: 658 / 0.57%
#    management_rec: 656 / 0.57%
#    other_notes: 114914 / 99.88%
#    vote_id: 0 / 0.0%
#
# --- Sample Rows ---
#    form_id               issuer_name      cusip          isin figi  \
# 0        4             Novavax, Inc.  670002401  US6700024010  NaN
# 1        4             Novavax, Inc.  670002401  US6700024010  NaN
# 2        4  FG Annuities  Life, Inc.  30190A104  US30190A1043  NaN
#
#   meeting_date                                   vote_description proposed_by  \
# 0   2023-07-11  The approval, on an advisory basis, of the com...         NaN
# 1   2023-07-11  The approval, on an advisory basis, of holding...         NaN
# 2   2023-07-12  Approval of a non-binding advisory resolution ...         NaN
#
#    shares_voted  shares_on_loan vote_cast  vote_cast_shares management_rec  \
# 0       45825.0             0.0       FOR           45825.0            FOR
# 1       45825.0             0.0  ONE YEAR           45825.0            FOR
# 2         108.0             0.0       FOR             108.0            FOR
#
#   other_notes  vote_id
# 0         NaN        1
# 1         NaN        2
# 2         NaN        3
#
# No duplicate rows found.
#
# === Data Quality Report: matter_category ===
# Shape: 15 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    15 non-null     int64
#  1   category_type  15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    category_id: 0 / 0.0%
#    category_type: 0 / 0.0%
#
# --- Sample Rows ---
#    category_id                 category_type
# 0            1  SECTION 14A SAY-ON-PAY VOTES
# 1            2    EXTRAORDINARY TRANSACTIONS
# 2            3          CORPORATE GOVERNANCE
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record_category ===
# Shape: 120051 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120051 entries, 0 to 120050
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   vote_id      120051 non-null  int64
#  1   category_id  120051 non-null  int64
# dtypes: int64(2)
# memory usage: 1.8 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    category_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  category_id
# 0        1            1
# 1        2            1
# 2        3            1
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_manager ===
# Shape: 1558 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1558 entries, 0 to 1557
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vote_id     1558 non-null   int64
#  1   manager_id  1558 non-null   int64
# dtypes: int64(2)
# memory usage: 24.5 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    manager_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  manager_id
# 0        1           1
# 1        2           2
# 2        3           3
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_series ===
# Shape: 113332 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113332 entries, 0 to 113331
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   vote_id    113332 non-null  int64
#  1   series_id  113332 non-null  int64
# dtypes: int64(2)
# memory usage: 1.7 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    series_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  series_id
# 0        1          1
# 1        2          2
# 2        3          3
#
# No duplicate rows found.

# %%
#############################################################
#  CELL 4: Additional Cross-Checks (Optional)
#############################################################

# Example cross-check: Ensure that proxy_voting_record_category.vote_id 
# actually exists in proxy_voting_record.vote_id
if dfs["proxy_voting_record"] is not None and not dfs["proxy_voting_record"].empty:
    if dfs["proxy_voting_record_category"] is not None and not dfs["proxy_voting_record_category"].empty:
        # Put them in sets for quick membership test
        valid_vote_ids = set(dfs["proxy_voting_record"]["vote_id"].dropna().unique())
        cat_vote_ids = set(dfs["proxy_voting_record_category"]["vote_id"].dropna().unique())
        
        missing_vote_ids = cat_vote_ids - valid_vote_ids
        if missing_vote_ids:
            print(f"\n[Cross-check] Found {len(missing_vote_ids)} vote_id(s) in proxy_voting_record_category not in proxy_voting_record.")
            print("Missing IDs:", missing_vote_ids)
        else:
            print("\n[Cross-check] All category vote_ids exist in proxy_voting_record!")

# You can similarly check that 'form_id' in institutional_manager, series, etc. 
# actually appears in form_npx.
# Out:
# [Cross-check] All category vote_ids exist in proxy_voting_record!
