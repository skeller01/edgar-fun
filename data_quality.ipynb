# %%
#############################################################
#  CELL 1: Markdown
#############################################################

# Example text for a Markdown cell:
"""
# Data Quality Report for N-PX CSV Outputs

This notebook performs basic data quality checks on the CSV files generated
by the N-PX parsing workflow. We’ll look for:

1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).
2. **Column-level stats**: For each column, how many nulls or missing values?
3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?
4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.

Feel free to add more custom checks, such as:
- Checking valid ranges for numeric columns.
- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).
- Checking that enumerated columns contain only valid values.

Let's begin!
"""
# Out:
# "\n# Data Quality Report for N-PX CSV Outputs\n\nThis notebook performs basic data quality checks on the CSV files generated\nby the N-PX parsing workflow. We’ll look for:\n\n1. **Row counts**: Ensure each table has at least some rows (unless empty is valid).\n2. **Column-level stats**: For each column, how many nulls or missing values?\n3. **Duplicate checks**: Are there any suspicious duplicates (e.g., form_id repeated with same data)?\n4. **Value distributions**: (Optional) Look at distinct categories in certain key fields.\n\nFeel free to add more custom checks, such as:\n- Checking valid ranges for numeric columns.\n- Checking that foreign key relationships align (e.g., `vote_id` in `proxy_voting_record_category` is found in `proxy_voting_record`).\n- Checking that enumerated columns contain only valid values.\n\nLet's begin!\n"

# %%
#############################################################
#  CELL 2: Imports & Setup
#############################################################

import os
import pandas as pd

# Point this to the folder where your CSVs are stored
CSV_FOLDER = "output"

# List your tables and corresponding file names
CSV_FILES = {
    "form_npx": "form_npx.csv",
    "institutional_manager": "institutional_manager.csv",
    "series": "series.csv",
    "proxy_voting_record": "proxy_voting_record.csv",
    "matter_category": "matter_category.csv",
    "proxy_voting_record_category": "proxy_voting_record_category.csv",
    "voting_record_manager": "voting_record_manager.csv",
    "voting_record_series": "voting_record_series.csv"
}

# We'll load all of them into a dict of DataFrames.
dfs = {}
for table_name, file_name in CSV_FILES.items():
    path = os.path.join(CSV_FOLDER, file_name)
    if os.path.exists(path):
        df = pd.read_csv(path)
        dfs[table_name] = df
    else:
        print(f"[Warning] {file_name} not found in {CSV_FOLDER}!")
        dfs[table_name] = None

print("DataFrames loaded:")
for k,v in dfs.items():
    if v is not None:
        print(f" - {k}: {len(v)} rows")
    else:
        print(f" - {k}: No data (file missing).")
# Out:
# C:\Users\skell\AppData\Local\Temp\ipykernel_17784\2531012235.py:28: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# DataFrames loaded:
#  - form_npx: 100 rows
#  - institutional_manager: 28 rows
#  - series: 110 rows
#  - proxy_voting_record: 185277 rows
#  - matter_category: 15 rows
#  - proxy_voting_record_category: 195763 rows
#  - voting_record_manager: 52029 rows
#  - voting_record_series: 177519 rows

# %%
#############################################################
#  CELL 3: Basic Data Quality Checks
#############################################################

# We’ll create a function to do quick checks on a given DataFrame.
def data_quality_report(df, df_name):
    """
    Print a small summary of data quality for a given DataFrame:
    1. Number of rows & columns
    2. Column data types & non-null counts
    3. Percent missing per column
    4. Sample records (head)
    """
    print(f"\n=== Data Quality Report: {df_name} ===")

    if df is None or df.empty:
        print("No data or empty DataFrame!")
        return

    # 1) Shape
    print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")

    # 2) Info
    print("\n--- Info ---")
    print(df.info())

    # 3) Missing values
    print("\n--- Missing Values (absolute / percent) ---")
    missing_count = df.isna().sum()
    missing_percent = (df.isna().mean() * 100).round(2)
    for col in df.columns:
        print(f"   {col}: {missing_count[col]} / {missing_percent[col]}%")

    # 4) Quick sample
    print("\n--- Sample Rows ---")
    print(df.head(3))

    # 5) (Optional) Check for duplicates. For small tables, a naive approach:
    #    We won't fix them here, just report.
    dup_count = df.duplicated().sum()
    if dup_count > 0:
        print(f"\n[Warning] {dup_count} duplicate row(s) found in {df_name}.")
    else:
        print("\nNo duplicate rows found.")

    # 6) (Optional) If you have a PK column, check duplicates in that PK:
    # if "form_id" in df.columns:
    #    pk_dup_count = df.duplicated(subset=["form_id"]).sum()
    #    if pk_dup_count > 0:
    #        print(f"[Warning] form_id has {pk_dup_count} duplicates!")
    #    else:
    #        print("form_id column is unique.")


# Now run the data_quality_report for each table
for table_name, df in dfs.items():
    data_quality_report(df, table_name)
# Out:
# === Data Quality Report: form_npx ===
# Shape: 100 rows x 39 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   form_type                       100 non-null    object
#  1   registrant_type                 100 non-null    object
#  2   live_test_flag                  100 non-null    object
#  3   cik                             100 non-null    int64
#  4   phone_number                    100 non-null    object
#  5   investment_company_type         30 non-null     object
#  6   conformed_period                100 non-null    object
#  7   year_or_quarter                 100 non-null    object
#  8   report_calendar_year            99 non-null     float64
#  9   report_quarter_year             1 non-null      float64
#  10  report_type                     100 non-null    object
#  11  confidential_treatment          100 non-null    object
#  12  notice_explanation              0 non-null      float64
#  13  is_notice_report                100 non-null    bool
#  14  is_amendment                    100 non-null    bool
#  15  amendment_no                    0 non-null      float64
#  16  amendment_type                  0 non-null      float64
#  17  reason_for_non_confidentiality  0 non-null      float64
#  18  reporting_crd_number            36 non-null     float64
#  19  reporting_sec_file_number       28 non-null     object
#  20  lei_number                      24 non-null     object
#  21  sec_file_number                 100 non-null    object
#  22  explanatory_choice              100 non-null    object
#  23  explanatory_notes               9 non-null      object
#  24  other_included_managers_count   100 non-null    int64
#  25  reporting_person_name           100 non-null    object
#  26  address_street1                 100 non-null    object
#  27  address_street2                 52 non-null     object
#  28  address_city                    100 non-null    object
#  29  address_state                   100 non-null    object
#  30  address_country                 100 non-null    object
#  31  address_zip                     100 non-null    object
#  32  signatory_name                  100 non-null    object
#  33  signatory_name_printed          100 non-null    object
#  34  signatory_title                 100 non-null    object
#  35  signatory_date                  100 non-null    object
#  36  accession_number                100 non-null    object
#  37  date_filed                      100 non-null    object
#  38  form_id                         100 non-null    int64
# dtypes: bool(2), float64(7), int64(3), object(27)
# memory usage: 29.2+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_type: 0 / 0.0%
#    registrant_type: 0 / 0.0%
#    live_test_flag: 0 / 0.0%
#    cik: 0 / 0.0%
#    phone_number: 0 / 0.0%
#    investment_company_type: 70 / 70.0%
#    conformed_period: 0 / 0.0%
#    year_or_quarter: 0 / 0.0%
#    report_calendar_year: 1 / 1.0%
#    report_quarter_year: 99 / 99.0%
#    report_type: 0 / 0.0%
#    confidential_treatment: 0 / 0.0%
#    notice_explanation: 100 / 100.0%
#    is_notice_report: 0 / 0.0%
#    is_amendment: 0 / 0.0%
#    amendment_no: 100 / 100.0%
#    amendment_type: 100 / 100.0%
#    reason_for_non_confidentiality: 100 / 100.0%
#    reporting_crd_number: 64 / 64.0%
#    reporting_sec_file_number: 72 / 72.0%
#    lei_number: 76 / 76.0%
#    sec_file_number: 0 / 0.0%
#    explanatory_choice: 0 / 0.0%
#    explanatory_notes: 91 / 91.0%
#    other_included_managers_count: 0 / 0.0%
#    reporting_person_name: 0 / 0.0%
#    address_street1: 0 / 0.0%
#    address_street2: 48 / 48.0%
#    address_city: 0 / 0.0%
#    address_state: 0 / 0.0%
#    address_country: 0 / 0.0%
#    address_zip: 0 / 0.0%
#    signatory_name: 0 / 0.0%
#    signatory_name_printed: 0 / 0.0%
#    signatory_title: 0 / 0.0%
#    signatory_date: 0 / 0.0%
#    accession_number: 0 / 0.0%
#    date_filed: 0 / 0.0%
#    form_id: 0 / 0.0%
#
# --- Sample Rows ---
#   form_type registrant_type live_test_flag      cik  phone_number  \
# 0      N-PX              IM           LIVE  1536924    6157623163
# 1      N-PX              IM           LIVE  1588456  239-254-2500
# 2      N-PX              IM           LIVE  1639997  336-725-5579
#
#   investment_company_type conformed_period year_or_quarter  \
# 0                     NaN       2024-06-30            YEAR
# 1                     NaN       2024-06-30            YEAR
# 2                     NaN       2024-06-30            YEAR
#
#    report_calendar_year  report_quarter_year  ... address_state  \
# 0                2024.0                  NaN  ...            TN
# 1                2024.0                  NaN  ...            FL
# 2                2024.0                  NaN  ...            NC
#
#   address_country  address_zip  signatory_name  signatory_name_printed  \
# 0              TN        37027     Tracey Hill             Tracey Hill
# 1              FL        34108  Chad D. Atkins          Chad D. Atkins
# 2              NC        27104  Harry Shertzer          Harry Shertzer
#
#                               signatory_title  signatory_date  \
# 0                    Chief Compliance Officer      2024-07-01
# 1                           President and CCO      2024-07-12
# 2  Portfolio Manager/Chief Compliance Officer      2024-07-15
#
#        accession_number  date_filed form_id
# 0  0001536924-24-000004  2024-07-01       1
# 1  0001214659-24-012298  2024-07-12       2
# 2  0001376474-24-000319  2024-07-16       3
#
# [3 rows x 39 columns]
#
# No duplicate rows found.
#
# === Data Quality Report: institutional_manager ===
# Shape: 28 rows x 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manager_id       28 non-null     int64
#  1   form_id          28 non-null     int64
#  2   serial_no        23 non-null     float64
#  3   name             23 non-null     object
#  4   form13f_number   23 non-null     object
#  5   crd_number       9 non-null      float64
#  6   sec_file_number  8 non-null      object
#  7   lei_number       10 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.9+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    manager_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    serial_no: 5 / 17.86%
#    name: 5 / 17.86%
#    form13f_number: 5 / 17.86%
#    crd_number: 19 / 67.86%
#    sec_file_number: 20 / 71.43%
#    lei_number: 18 / 64.29%
#
# --- Sample Rows ---
#    manager_id  form_id  serial_no                              name  \
# 0           1       18      801.0                 William Oldfather
# 1           2       30        1.0           Citizens  Northern Bank
# 2           3       34        2.0  Loomis Sayles Trust Company, LLC
#
#   form13f_number  crd_number sec_file_number            lei_number
# 0      028-19711    112505.0             NaN                   NaN
# 1       28-14473         NaN             NaN                   NaN
# 2      028-13087         NaN             NaN  549300DZZSM2BX1KLV04
#
# No duplicate rows found.
#
# === Data Quality Report: series ===
# Shape: 110 rows x 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   series_id    110 non-null    int64
#  1   form_id      110 non-null    int64
#  2   series_code  110 non-null    object
#  3   series_name  110 non-null    object
#  4   series_lei   110 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.4+ KB
# None
#
# --- Missing Values (absolute / percent) ---
#    series_id: 0 / 0.0%
#    form_id: 0 / 0.0%
#    series_code: 0 / 0.0%
#    series_name: 0 / 0.0%
#    series_lei: 0 / 0.0%
#
# --- Sample Rows ---
#    series_id  form_id series_code                               series_name  \
# 0          1       27  S000079052       Altegris Crabel Multi-Strategy Fund
# 1          2       27  S000034148  Altegris Futures Evolution Strategy Fund
# 2          3       27  S000030708              Beech Hill Total Return Fund
#
#              series_lei
# 0  549300NCUJCIKLMSHE04
# 1  549300QS50K1YX3VUM61
# 2  54930008EEZ1S4P4XT27
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record ===
# Shape: 185277 rows x 15 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185277 entries, 0 to 185276
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   form_id           185277 non-null  int64
#  1   issuer_name       185277 non-null  object
#  2   cusip             178953 non-null  object
#  3   isin              170567 non-null  object
#  4   figi              63 non-null      object
#  5   meeting_date      185276 non-null  object
#  6   vote_description  185277 non-null  object
#  7   proposed_by       181267 non-null  object
#  8   shares_voted      185276 non-null  float64
#  9   shares_on_loan    185276 non-null  float64
#  10  vote_cast         180327 non-null  object
#  11  vote_cast_shares  180522 non-null  float64
#  12  management_rec    180524 non-null  object
#  13  other_notes       172 non-null     object
#  14  vote_id           185277 non-null  int64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 21.2+ MB
# None
#
# --- Missing Values (absolute / percent) ---
#    form_id: 0 / 0.0%
#    issuer_name: 0 / 0.0%
#    cusip: 6324 / 3.41%
#    isin: 14710 / 7.94%
#    figi: 185214 / 99.97%
#    meeting_date: 1 / 0.0%
#    vote_description: 0 / 0.0%
#    proposed_by: 4010 / 2.16%
#    shares_voted: 1 / 0.0%
#    shares_on_loan: 1 / 0.0%
#    vote_cast: 4950 / 2.67%
#    vote_cast_shares: 4755 / 2.57%
#    management_rec: 4753 / 2.57%
#    other_notes: 185105 / 99.91%
#    vote_id: 0 / 0.0%
#
# --- Sample Rows ---
#    form_id              issuer_name      cusip          isin figi  \
# 0        2  CRA International, Inc.  12618T105  US12618T1051  NaN
# 1        2  CRA International, Inc.  12618T105  US12618T1051  NaN
# 2        2         PowerFleet, Inc.  73931J109  US73931J1097  NaN
#
#   meeting_date                                   vote_description proposed_by  \
# 0   2023-07-13  To approve, on an advisory basis, the compensa...         NaN
# 1   2023-07-13  To approve, on an advisory basis, the preferre...         NaN
# 2   2023-07-20  Advisory approval of the Company's executive c...         NaN
#
#    shares_voted  shares_on_loan vote_cast  vote_cast_shares management_rec  \
# 0       68507.0             0.0       FOR           68507.0            FOR
# 1       68507.0             0.0    1 YEAR           68507.0            FOR
# 2     4255350.0             0.0       FOR         4255350.0            FOR
#
#   other_notes  vote_id
# 0         NaN        1
# 1         NaN        2
# 2         NaN        3
#
# No duplicate rows found.
#
# === Data Quality Report: matter_category ===
# Shape: 15 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    15 non-null     int64
#  1   category_type  15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes
# None
#
# --- Missing Values (absolute / percent) ---
#    category_id: 0 / 0.0%
#    category_type: 0 / 0.0%
#
# --- Sample Rows ---
#    category_id                 category_type
# 0            1  SECTION 14A SAY-ON-PAY VOTES
# 1            2                  COMPENSATION
# 2            3            DIRECTOR ELECTIONS
#
# No duplicate rows found.
#
# === Data Quality Report: proxy_voting_record_category ===
# Shape: 195763 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195763 entries, 0 to 195762
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   vote_id      195763 non-null  int64
#  1   category_id  195763 non-null  int64
# dtypes: int64(2)
# memory usage: 3.0 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    category_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  category_id
# 0        1            1
# 1        2            1
# 2        3            1
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_manager ===
# Shape: 52029 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52029 entries, 0 to 52028
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vote_id     52029 non-null  int64
#  1   manager_id  52029 non-null  int64
# dtypes: int64(2)
# memory usage: 813.1 KB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    manager_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  manager_id
# 0        1           1
# 1        2           2
# 2        3           3
#
# No duplicate rows found.
#
# === Data Quality Report: voting_record_series ===
# Shape: 177519 rows x 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177519 entries, 0 to 177518
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   vote_id    177519 non-null  int64
#  1   series_id  177519 non-null  int64
# dtypes: int64(2)
# memory usage: 2.7 MB
# None
#
# --- Missing Values (absolute / percent) ---
#    vote_id: 0 / 0.0%
#    series_id: 0 / 0.0%
#
# --- Sample Rows ---
#    vote_id  series_id
# 0        1          1
# 1        2          2
# 2        3          3
#
# No duplicate rows found.

# %%
#############################################################
#  CELL 4: Additional Cross-Checks (Optional)
#############################################################

# Example cross-check: Ensure that proxy_voting_record_category.vote_id 
# actually exists in proxy_voting_record.vote_id
if dfs["proxy_voting_record"] is not None and not dfs["proxy_voting_record"].empty:
    if dfs["proxy_voting_record_category"] is not None and not dfs["proxy_voting_record_category"].empty:
        # Put them in sets for quick membership test
        valid_vote_ids = set(dfs["proxy_voting_record"]["vote_id"].dropna().unique())
        cat_vote_ids = set(dfs["proxy_voting_record_category"]["vote_id"].dropna().unique())
        
        missing_vote_ids = cat_vote_ids - valid_vote_ids
        if missing_vote_ids:
            print(f"\n[Cross-check] Found {len(missing_vote_ids)} vote_id(s) in proxy_voting_record_category not in proxy_voting_record.")
            print("Missing IDs:", missing_vote_ids)
        else:
            print("\n[Cross-check] All category vote_ids exist in proxy_voting_record!")

# You can similarly check that 'form_id' in institutional_manager, series, etc. 
# actually appears in form_npx.
# Out:
# [Cross-check] All category vote_ids exist in proxy_voting_record!
